# %% [markdown]
# # JAT PostgreSQL Client — Smoke Tests
#
# This notebook exercises the `jupyter_agent_toolkit.db.postgresql` client:
#
# - `ConnectionManager` & `PostgresClient`
# - Schema discovery: `list_tables`, `list_columns`, `schema(...)`
# - Query helpers: `query_rows`, `query_df`, `stream_to_parquet(...)`
# - EXPLAIN plans: text & JSON
# - Pooling & session settings

# %% [markdown]
# ## In the notebook kernel (or wherever the kernel's packages are installed)
#
# ```bash
# !pip install -U "jupyter-agent-toolkit[postgresql]"
# ```

# %% [markdown]
# ## Get Environment Variables

# %%
import logging
from dotenv import load_dotenv

# %%
logging.basicConfig(level=logging.INFO)
load_dotenv()
# Out:
# True

# %%
import os

# Option A: use env vars (recommended)
# Set one of: PG_DSN, POSTGRES_DSN, or DATABASE_URL before running this notebook
# Example: os.environ["PG_DSN"] = "postgresql://user:pass@localhost:5432/dbname"

# Option B: specify DSN directly here (for testing only)
DSN = os.getenv("PG_DSN") or os.getenv("POSTGRES_DSN") or os.getenv("DATABASE_URL")
if not DSN:
    # Fallback example — change this to your DB if you want to hardcode:
    # DSN = "postgresql://user:pass@localhost:5432/postgres"
    raise RuntimeError("Please set PG_DSN / POSTGRES_DSN / DATABASE_URL for this kernel.")

# %% [markdown]
# ## Initialize Postgresql Connections

# %%
from jupyter_agent_toolkit.db import PostgresClient
import pandas as pd

pd.set_option("display.max_rows", 10)
pd.set_option("display.max_colwidth", 120)

pg = PostgresClient.from_dsn(DSN)

# %% [markdown]
# ## List Tables

# %%
tables = pg.list_tables()  # all schemas
len(tables), tables[:5]
# Out:
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Attempting to connect to PostgreSQL server (driver=postgresql user=postgres host=81f2b39e7e39-kezexvzxwazam-postgresql.postgres.database.azure.com port=None db=incident_5 sslmode=None).
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Connection established successfully.
# (241,
#  [{'table_schema': 'information_schema',
#    'table_name': '_pg_foreign_data_wrappers',
#    'table_type': 'VIEW'},
#   {'table_schema': 'information_schema',
#    'table_name': '_pg_foreign_servers',
#    'table_type': 'VIEW'},
#   {'table_schema': 'information_schema',
#    'table_name': '_pg_foreign_table_columns',
#    'table_type': 'VIEW'},
#   {'table_schema': 'information_schema',
#    'table_name': '_pg_foreign_tables',
#    'table_type': 'VIEW'},
#   {'table_schema': 'information_schema',
#    'table_name': '_pg_user_mappings',
#    'table_type': 'VIEW'}])

# %% [markdown]
# ## Inspect Columns

# %%
# Try to pick the first table from "public" or fallback to the first row
public_tbls = [t for t in tables if t["table_schema"] == "public"]
if not public_tbls and tables:
    public_tbls = [tables[0]]

if not public_tbls:
    raise RuntimeError("No tables found. Create a table and rerun.")

schema_name = public_tbls[0]["table_schema"]
table_name = public_tbls[0]["table_name"]
schema_name, table_name
# Out:
# ('public', 'AADManagedIdentitySignInLogs')

# %% [markdown]
# ## Full Schema Snapshot

# %%
sch = pg.schema(schema_name=schema_name, table=table_name, include_indexes=True, include_constraints=True)
list(sch.keys()), len(sch.get("columns", []))
# Out:
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Attempting to connect to PostgreSQL server (driver=postgresql user=postgres host=81f2b39e7e39-kezexvzxwazam-postgresql.postgres.database.azure.com port=None db=incident_5 sslmode=None).
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Connection established successfully.
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Attempting to connect to PostgreSQL server (driver=postgresql user=postgres host=81f2b39e7e39-kezexvzxwazam-postgresql.postgres.database.azure.com port=None db=incident_5 sslmode=None).
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Connection established successfully.
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Attempting to connect to PostgreSQL server (driver=postgresql user=postgres host=81f2b39e7e39-kezexvzxwazam-postgresql.postgres.database.azure.com port=None db=incident_5 sslmode=None).
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Connection established successfully.
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Attempting to connect to PostgreSQL server (driver=postgresql user=postgres host=81f2b39e7e39-kezexvzxwazam-postgresql.postgres.database.azure.com port=None db=incident_5 sslmode=None).
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Connection established successfully.
# (['tables', 'columns', 'constraints', 'indexes'], 34)

# %% [markdown]
# ## Query Rows and Dataframe

# %% [markdown]
# ### Raw SQL

# %%
# --- Freeform SQL mode (raw SQL string) ---
sql = "SELECT * FROM public.\"AADManagedIdentitySignInLogs\" LIMIT 10"

rows = pg.query_rows(sql)

print(f"Returned {len(rows)} rows")
# Out:
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Attempting to connect to PostgreSQL server (driver=postgresql user=postgres host=81f2b39e7e39-kezexvzxwazam-postgresql.postgres.database.azure.com port=None db=incident_5 sslmode=None).
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Connection established successfully.
# Returned 10 rows

# %%
rows
# Out:
# [{'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 7, 6, 50, 851617),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '17334a39-8910-4f95-ab1e-17733db549d7',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '4f41751c-3c78-4232-b349-1b227f0ab213',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': 'ac95af6c-3ded-4c13-a628-51e3d57a7e00',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Azure Key Vault',
#   'ResourceIdentity': 'cfa8b339-82a2-471a-a3c9-0fc0be7a4093',
#   'ResourceServicePrincipalId': 'c821dfc2-9e75-435f-99ad-92e80a665f49',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': 'd006ead0-4bd7-49d4-a9a2-3da012b56cd6',
#   'ServicePrincipalName': 'SAP-Sentinel',
#   'UniqueTokenIdentifier': 'bK-VrO09E0ymKFHj1Xp-AA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 7, 52, 9, 463691),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '82fa5064-2540-47e4-b4f3-cffa5175124f',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '4f41751c-3c78-4232-b349-1b227f0ab213',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '14cfc93f-3405-4a29-9800-c257897c9300',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Azure Key Vault',
#   'ResourceIdentity': 'cfa8b339-82a2-471a-a3c9-0fc0be7a4093',
#   'ResourceServicePrincipalId': 'c821dfc2-9e75-435f-99ad-92e80a665f49',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': 'd006ead0-4bd7-49d4-a9a2-3da012b56cd6',
#   'ServicePrincipalName': 'SAP-Sentinel',
#   'UniqueTokenIdentifier': 'P8nPFAU0KUqYAMJXiXyTAA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 12, 35, 376077),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '9e8b46c8-fd5d-4dad-8700-3030ebe3f7f1',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': 'cb866557-18b7-49fb-b3c0-f84d0e3cf400',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': 'V2WGy7cY-0mzwPhNDjz0AA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 12, 59, 457579),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '95e17110-c3d2-44f7-8de7-2596cea90c32',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '67c5f7e8-52c6-42bf-a870-26c0b2268500',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': '6PfFZ8ZSv0KocCbAsiaFAA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 13, 2, 318705),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': 'ee96bf8e-8798-48cc-a59e-4975fae36bc9',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '1831de28-db05-483f-8d69-7e7abac4bc00',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': 'KN4xGAXbP0iNaX56usS8AA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 13, 3, 772874),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '6cff50d9-d710-4708-a52a-f77de1192578',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '73c391e4-cbc7-4c71-916b-22f0a860a500',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': '5JHDc8fLcUyRayLwqGClAA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 13, 22, 871337),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '891b9e71-3a3e-460d-a620-ba102e0f491b',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '9ddb6854-357a-460f-ae78-c25aca828400',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': 'VGjbnXo1D0aueMJayoKEAA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 13, 31, 211424),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '3b4d6914-b106-4f70-ae46-d4a0827aadc6',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '39a919cb-3073-4041-8092-5c5a1c819200',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': 'yxmpOXMwQUCAklxaHIGSAA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 13, 53, 236636),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': 'baf998b9-75c2-423b-a4dc-9d99bffa822e',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '8d6d326f-5307-4bc3-a9fd-82db737fe600',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': 'bzJtjQdTw0up_YLbc3_mAA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 13, 53, 490480),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '808faf68-2a2e-43f6-bf4a-3b9b40a824bb',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '23208fcf-278f-44f6-bef8-547e09ded400',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': 'z48gI48n9kS--FR-Cd7UAA',
#   'Type': 'AADManagedIdentitySignInLogs'}]

# %%
df   = pg.query_df(sql)
df.head()
# Out:
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Attempting to connect to PostgreSQL server (driver=postgresql user=postgres host=81f2b39e7e39-kezexvzxwazam-postgresql.postgres.database.azure.com port=None db=incident_5 sslmode=None).
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Connection established successfully.
#                                TenantId SourceSystem  \
# 0  e34d562e-ef12-4c4e-9bc0-7c6ae357c015     Azure AD
# 1  e34d562e-ef12-4c4e-9bc0-7c6ae357c015     Azure AD
# 2  e34d562e-ef12-4c4e-9bc0-7c6ae357c015     Azure AD
# 3  e34d562e-ef12-4c4e-9bc0-7c6ae357c015     Azure AD
# 4  e34d562e-ef12-4c4e-9bc0-7c6ae357c015     Azure AD
#
#                TimeGenerated     OperationName OperationVersion  \
# 0 2024-06-20 07:06:50.851617  Sign-in activity              1.0
# 1 2024-06-20 07:52:09.463691  Sign-in activity              1.0
# 2 2024-06-20 08:12:35.376077  Sign-in activity              1.0
# 3 2024-06-20 08:12:59.457579  Sign-in activity              1.0
# 4 2024-06-20 08:13:02.318705  Sign-in activity              1.0
#
#                     Category ResultType ResultSignature ResultDescription  \
# 0  ManagedIdentitySignInLogs          0            None              None
# 1  ManagedIdentitySignInLogs          0            None              None
# 2  ManagedIdentitySignInLogs          0            None              None
# 3  ManagedIdentitySignInLogs          0            None              None
# 4  ManagedIdentitySignInLogs          0            None              None
#
#    DurationMs  ...  \
# 0           0  ...
# 1           0  ...
# 2           0  ...
# 3           0  ...
# 4           0  ...
#
#                                                                                  LocationDetails  \
# 0  {"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}
# 1  {"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}
# 2  {"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}
# 3  {"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}
# 4  {"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}
#
#                     ResourceDisplayName                      ResourceIdentity  \
# 0                       Azure Key Vault  cfa8b339-82a2-471a-a3c9-0fc0be7a4093
# 1                       Azure Key Vault  cfa8b339-82a2-471a-a3c9-0fc0be7a4093
# 2  Windows Azure Service Management API  1e0cacf9-ff0c-4d91-8497-79b618eecab3
# 3  Windows Azure Service Management API  1e0cacf9-ff0c-4d91-8497-79b618eecab3
# 4  Windows Azure Service Management API  1e0cacf9-ff0c-4d91-8497-79b618eecab3
#
#              ResourceServicePrincipalId ServicePrincipalCredentialKeyId  \
# 0  c821dfc2-9e75-435f-99ad-92e80a665f49                            None
# 1  c821dfc2-9e75-435f-99ad-92e80a665f49                            None
# 2  ad891bca-afbc-464b-866d-d9efaf062e58                            None
# 3  ad891bca-afbc-464b-866d-d9efaf062e58                            None
# 4  ad891bca-afbc-464b-866d-d9efaf062e58                            None
#
#   ServicePrincipalCredentialThumbprint                    ServicePrincipalId  \
# 0                                 None  d006ead0-4bd7-49d4-a9a2-3da012b56cd6
# 1                                 None  d006ead0-4bd7-49d4-a9a2-3da012b56cd6
# 2                                 None  5ac54904-f3f6-444a-b099-14726ab1a733
# 3                                 None  5ac54904-f3f6-444a-b099-14726ab1a733
# 4                                 None  5ac54904-f3f6-444a-b099-14726ab1a733
#
#   ServicePrincipalName   UniqueTokenIdentifier                          Type
# 0         SAP-Sentinel  bK-VrO09E0ymKFHj1Xp-AA  AADManagedIdentitySignInLogs
# 1         SAP-Sentinel  P8nPFAU0KUqYAMJXiXyTAA  AADManagedIdentitySignInLogs
# 2       StartStopVMLia  V2WGy7cY-0mzwPhNDjz0AA  AADManagedIdentitySignInLogs
# 3       StartStopVMLia  6PfFZ8ZSv0KocCbAsiaFAA  AADManagedIdentitySignInLogs
# 4       StartStopVMLia  KN4xGAXbP0iNaX56usS8AA  AADManagedIdentitySignInLogs
#
# [5 rows x 34 columns]

# %%
rows2 = pg.query_rows(schema_name="public", table_name="AADManagedIdentitySignInLogs", limit=10)

print(f"Returned {len(rows2)} rows")
# Out:
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Attempting to connect to PostgreSQL server (driver=postgresql user=postgres host=81f2b39e7e39-kezexvzxwazam-postgresql.postgres.database.azure.com port=None db=incident_5 sslmode=None).
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Connection established successfully.
# Returned 10 rows

# %%
rows2
# Out:
# [{'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 7, 6, 50, 851617),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '17334a39-8910-4f95-ab1e-17733db549d7',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '4f41751c-3c78-4232-b349-1b227f0ab213',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': 'ac95af6c-3ded-4c13-a628-51e3d57a7e00',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Azure Key Vault',
#   'ResourceIdentity': 'cfa8b339-82a2-471a-a3c9-0fc0be7a4093',
#   'ResourceServicePrincipalId': 'c821dfc2-9e75-435f-99ad-92e80a665f49',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': 'd006ead0-4bd7-49d4-a9a2-3da012b56cd6',
#   'ServicePrincipalName': 'SAP-Sentinel',
#   'UniqueTokenIdentifier': 'bK-VrO09E0ymKFHj1Xp-AA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 7, 52, 9, 463691),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '82fa5064-2540-47e4-b4f3-cffa5175124f',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '4f41751c-3c78-4232-b349-1b227f0ab213',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '14cfc93f-3405-4a29-9800-c257897c9300',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Azure Key Vault',
#   'ResourceIdentity': 'cfa8b339-82a2-471a-a3c9-0fc0be7a4093',
#   'ResourceServicePrincipalId': 'c821dfc2-9e75-435f-99ad-92e80a665f49',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': 'd006ead0-4bd7-49d4-a9a2-3da012b56cd6',
#   'ServicePrincipalName': 'SAP-Sentinel',
#   'UniqueTokenIdentifier': 'P8nPFAU0KUqYAMJXiXyTAA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 12, 35, 376077),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '9e8b46c8-fd5d-4dad-8700-3030ebe3f7f1',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': 'cb866557-18b7-49fb-b3c0-f84d0e3cf400',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': 'V2WGy7cY-0mzwPhNDjz0AA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 12, 59, 457579),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '95e17110-c3d2-44f7-8de7-2596cea90c32',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '67c5f7e8-52c6-42bf-a870-26c0b2268500',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': '6PfFZ8ZSv0KocCbAsiaFAA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 13, 2, 318705),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': 'ee96bf8e-8798-48cc-a59e-4975fae36bc9',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '1831de28-db05-483f-8d69-7e7abac4bc00',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': 'KN4xGAXbP0iNaX56usS8AA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 13, 3, 772874),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '6cff50d9-d710-4708-a52a-f77de1192578',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '73c391e4-cbc7-4c71-916b-22f0a860a500',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': '5JHDc8fLcUyRayLwqGClAA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 13, 22, 871337),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '891b9e71-3a3e-460d-a620-ba102e0f491b',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '9ddb6854-357a-460f-ae78-c25aca828400',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': 'VGjbnXo1D0aueMJayoKEAA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 13, 31, 211424),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '3b4d6914-b106-4f70-ae46-d4a0827aadc6',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '39a919cb-3073-4041-8092-5c5a1c819200',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': 'yxmpOXMwQUCAklxaHIGSAA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 13, 53, 236636),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': 'baf998b9-75c2-423b-a4dc-9d99bffa822e',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '8d6d326f-5307-4bc3-a9fd-82db737fe600',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': 'bzJtjQdTw0up_YLbc3_mAA',
#   'Type': 'AADManagedIdentitySignInLogs'},
#  {'TenantId': 'e34d562e-ef12-4c4e-9bc0-7c6ae357c015',
#   'SourceSystem': 'Azure AD',
#   'TimeGenerated': datetime.datetime(2024, 6, 20, 8, 13, 53, 490480),
#   'OperationName': 'Sign-in activity',
#   'OperationVersion': '1.0',
#   'Category': 'ManagedIdentitySignInLogs',
#   'ResultType': '0',
#   'ResultSignature': None,
#   'ResultDescription': None,
#   'DurationMs': 0,
#   'CorrelationId': '808faf68-2a2e-43f6-bf4a-3b9b40a824bb',
#   'ResourceGroup': 'Microsoft.aadiam',
#   'Identity': None,
#   'Level': None,
#   'Location': None,
#   'AppId': '8e398334-fb62-47d1-b638-fa3618acb124',
#   'AuthenticationContextClassReferences': None,
#   'AuthenticationProcessingDetails': '[]',
#   'ConditionalAccessPolicies': '[]',
#   'ConditionalAccessPoliciesV2': {},
#   'ConditionalAccessStatus': 'notApplied',
#   'FederatedCredentialId': None,
#   'Id': '23208fcf-278f-44f6-bef8-547e09ded400',
#   'IPAddress': None,
#   'LocationDetails': '{"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}',
#   'ResourceDisplayName': 'Windows Azure Service Management API',
#   'ResourceIdentity': '1e0cacf9-ff0c-4d91-8497-79b618eecab3',
#   'ResourceServicePrincipalId': 'ad891bca-afbc-464b-866d-d9efaf062e58',
#   'ServicePrincipalCredentialKeyId': None,
#   'ServicePrincipalCredentialThumbprint': None,
#   'ServicePrincipalId': '5ac54904-f3f6-444a-b099-14726ab1a733',
#   'ServicePrincipalName': 'StartStopVMLia',
#   'UniqueTokenIdentifier': 'z48gI48n9kS--FR-Cd7UAA',
#   'Type': 'AADManagedIdentitySignInLogs'}]

# %%
df2   = pg.query_df(schema_name="public", table_name="AADManagedIdentitySignInLogs", limit=10)
# Out:
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Attempting to connect to PostgreSQL server (driver=postgresql user=postgres host=81f2b39e7e39-kezexvzxwazam-postgresql.postgres.database.azure.com port=None db=incident_5 sslmode=None).
# INFO:jupyter_agent_toolkit.db.postgresql.ConnectionManager:Connection established successfully.

# %%
df2.head()
# Out:
#                                TenantId SourceSystem  \
# 0  e34d562e-ef12-4c4e-9bc0-7c6ae357c015     Azure AD
# 1  e34d562e-ef12-4c4e-9bc0-7c6ae357c015     Azure AD
# 2  e34d562e-ef12-4c4e-9bc0-7c6ae357c015     Azure AD
# 3  e34d562e-ef12-4c4e-9bc0-7c6ae357c015     Azure AD
# 4  e34d562e-ef12-4c4e-9bc0-7c6ae357c015     Azure AD
#
#                TimeGenerated     OperationName OperationVersion  \
# 0 2024-06-20 07:06:50.851617  Sign-in activity              1.0
# 1 2024-06-20 07:52:09.463691  Sign-in activity              1.0
# 2 2024-06-20 08:12:35.376077  Sign-in activity              1.0
# 3 2024-06-20 08:12:59.457579  Sign-in activity              1.0
# 4 2024-06-20 08:13:02.318705  Sign-in activity              1.0
#
#                     Category ResultType ResultSignature ResultDescription  \
# 0  ManagedIdentitySignInLogs          0            None              None
# 1  ManagedIdentitySignInLogs          0            None              None
# 2  ManagedIdentitySignInLogs          0            None              None
# 3  ManagedIdentitySignInLogs          0            None              None
# 4  ManagedIdentitySignInLogs          0            None              None
#
#    DurationMs  ...  \
# 0           0  ...
# 1           0  ...
# 2           0  ...
# 3           0  ...
# 4           0  ...
#
#                                                                                  LocationDetails  \
# 0  {"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}
# 1  {"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}
# 2  {"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}
# 3  {"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}
# 4  {"city":"","state":"","countryOrRegion":"","geoCoordinates":{"latitude":0.0,"longitude":0.0}}
#
#                     ResourceDisplayName                      ResourceIdentity  \
# 0                       Azure Key Vault  cfa8b339-82a2-471a-a3c9-0fc0be7a4093
# 1                       Azure Key Vault  cfa8b339-82a2-471a-a3c9-0fc0be7a4093
# 2  Windows Azure Service Management API  1e0cacf9-ff0c-4d91-8497-79b618eecab3
# 3  Windows Azure Service Management API  1e0cacf9-ff0c-4d91-8497-79b618eecab3
# 4  Windows Azure Service Management API  1e0cacf9-ff0c-4d91-8497-79b618eecab3
#
#              ResourceServicePrincipalId ServicePrincipalCredentialKeyId  \
# 0  c821dfc2-9e75-435f-99ad-92e80a665f49                            None
# 1  c821dfc2-9e75-435f-99ad-92e80a665f49                            None
# 2  ad891bca-afbc-464b-866d-d9efaf062e58                            None
# 3  ad891bca-afbc-464b-866d-d9efaf062e58                            None
# 4  ad891bca-afbc-464b-866d-d9efaf062e58                            None
#
#   ServicePrincipalCredentialThumbprint                    ServicePrincipalId  \
# 0                                 None  d006ead0-4bd7-49d4-a9a2-3da012b56cd6
# 1                                 None  d006ead0-4bd7-49d4-a9a2-3da012b56cd6
# 2                                 None  5ac54904-f3f6-444a-b099-14726ab1a733
# 3                                 None  5ac54904-f3f6-444a-b099-14726ab1a733
# 4                                 None  5ac54904-f3f6-444a-b099-14726ab1a733
#
#   ServicePrincipalName   UniqueTokenIdentifier                          Type
# 0         SAP-Sentinel  bK-VrO09E0ymKFHj1Xp-AA  AADManagedIdentitySignInLogs
# 1         SAP-Sentinel  P8nPFAU0KUqYAMJXiXyTAA  AADManagedIdentitySignInLogs
# 2       StartStopVMLia  V2WGy7cY-0mzwPhNDjz0AA  AADManagedIdentitySignInLogs
# 3       StartStopVMLia  6PfFZ8ZSv0KocCbAsiaFAA  AADManagedIdentitySignInLogs
# 4       StartStopVMLia  KN4xGAXbP0iNaX56usS8AA  AADManagedIdentitySignInLogs
#
# [5 rows x 34 columns]
