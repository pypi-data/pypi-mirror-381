# %%
import pandas as pd

# %%
df = pd.read_csv("annotations.csv")

# %%
df
# Out:
#      Unnamed: 0  PatientID      age  clinical.T.Stage  Clinical.N.Stage  \
# 0             0  LUNG1-001  78.7515               2.0                 3
# 1             1  LUNG1-002  83.8001               2.0                 0
# 2             2  LUNG1-003  68.1807               2.0                 3
# 3             3  LUNG1-004  70.8802               2.0                 1
# 4             4  LUNG1-005  80.4819               4.0                 2
# ..          ...        ...      ...               ...               ...
# 416         416  LUNG1-418  53.6712               2.0                 0
# 417         417  LUNG1-419  66.5096               4.0                 1
# 418         418  LUNG1-420  73.3808               2.0                 1
# 419         419  LUNG1-421  61.7041               2.0                 2
# 420         420  LUNG1-422  68.1260               2.0                 0
#
#      Clinical.M.Stage Overall.Stage                Histology  gender  \
# 0                   0          IIIb               large cell    male
# 1                   0             I  squamous cell carcinoma    male
# 2                   0          IIIb               large cell    male
# 3                   0            II  squamous cell carcinoma    male
# 4                   0          IIIb  squamous cell carcinoma    male
# ..                ...           ...                      ...     ...
# 416                 0             I           adenocarcinoma    male
# 417                 0          IIIb  squamous cell carcinoma    male
# 418                 0            II  squamous cell carcinoma    male
# 419                 0          IIIa  squamous cell carcinoma  female
# 420                 0             I                      NaN  female
#
#      Survival.time  deadstatus.event     coordX      coordY      coordZ  \
# 0             2165                 1  82.300730 -201.481085 -456.837891
# 1              155                 1 -74.470257   16.355619  -18.734989
# 2              256                 1  47.427207   -2.460780 -127.246157
# 3              141                 1  59.826981   80.812406 -557.667118
# 4              353                 1 -58.787867    5.099882  -15.077542
# ..             ...               ...        ...         ...         ...
# 416            346                 1  58.077229 -147.448007 -403.310242
# 417           2772                 0 -76.557553 -207.936717 -486.269012
# 418           2429                 1  54.152849 -121.574490 -519.903226
# 419            369                 1  59.817083 -168.615061 -420.760008
# 420           1590                 1 -26.546391 -145.033635 -451.231140
#
#                                             image_path  survival
# 0    /mnt/data1/suraj/RadiomicsFoundationModel/LUNG...       1.0
# 1    /mnt/data1/suraj/RadiomicsFoundationModel/LUNG...       0.0
# 2    /mnt/data1/suraj/RadiomicsFoundationModel/LUNG...       0.0
# 3    /mnt/data1/suraj/RadiomicsFoundationModel/LUNG...       0.0
# 4    /mnt/data1/suraj/RadiomicsFoundationModel/LUNG...       0.0
# ..                                                 ...       ...
# 416  /mnt/data1/suraj/RadiomicsFoundationModel/LUNG...       0.0
# 417  /mnt/data1/suraj/RadiomicsFoundationModel/LUNG...       1.0
# 418  /mnt/data1/suraj/RadiomicsFoundationModel/LUNG...       1.0
# 419  /mnt/data1/suraj/RadiomicsFoundationModel/LUNG...       0.0
# 420  /mnt/data1/suraj/RadiomicsFoundationModel/LUNG...       1.0
#
# [421 rows x 16 columns]

# %%
# Split the data into training and validation sets
from sklearn.model_selection import train_test_split

train_df, val_test_df = train_test_split(df, test_size=0.5)
val_df, test_df = train_test_split(val_test_df, test_size=0.8)

train_df.to_csv("train_annotations.csv", index=False)
val_df.to_csv("val_annotations.csv", index=False)
test_df.to_csv("test_annotations.csv", index=False)
