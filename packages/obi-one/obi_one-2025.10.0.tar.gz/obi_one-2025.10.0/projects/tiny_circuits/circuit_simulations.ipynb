# %% [markdown]
# # Circuit simulation campaign setup for tiny circuits

# %%
import obi_one as obi
from pathlib import Path

# %%
circuit_path_prefix = Path("../../examples/data/tiny_circuits")

# %% [markdown]
# ### Loading a circuit

# %%
circuit = obi.Circuit(name="N_10__top_nodes_dim6", path=str(circuit_path_prefix / "N_10__top_nodes_dim6" / "circuit_config.json"))
nodes = circuit.sonata_circuit.nodes["S1nonbarrel_neurons"]
edges = circuit.sonata_circuit.edges["S1nonbarrel_neurons__S1nonbarrel_neurons__chemical"]
print(f"Circuit '{circuit}' with {nodes.size} neurons and {edges.size} synapses")
display(nodes.get())
# Out:
# Circuit 'N_10__top_nodes_dim6' with 10 neurons and 176 synapses
#            etype  exc_mini_frequency  inh_mini_frequency layer  \
# node_ids
# 0         cACint            0.010108            0.233243     3
# 1         cADpyr            0.010108            0.233243     6
# 2         cADpyr            0.010108            0.233243     6
# 3         cADpyr            0.010214            0.233243     6
# 4         cADpyr            0.010214            0.233243     6
# 5         cADpyr            0.010214            0.233243     6
# 6         cADpyr            0.003295            0.233243     6
# 7         cADpyr            0.003295            0.233243     6
# 8         cADpyr            0.003295            0.233243     6
# 9         cADpyr            0.003295            0.233243     6
#
#                                                    me_combo    model_template  \
# node_ids
# 0         cACint_L23MC_L23_CHC_3_mtC181200C_idA_-_Scale_...  hoc:cACint_L23MC
# 1         cADpyr_L6BPC_L6_BPC_6_dend-mtC090401A_idB_axon...  hoc:cADpyr_L6BPC
# 2         cADpyr_L6BPC_L6_BPC_6_dend-vd110330_idA_axon-t...  hoc:cADpyr_L6BPC
# 3         cADpyr_L6BPC_L6_IPC_6_dend-tkb060118b1_ch1_cc1...  hoc:cADpyr_L6BPC
# 4         cADpyr_L6BPC_L6_IPC_6_dend-Fluo18_lower_axon-r...  hoc:cADpyr_L6BPC
# 5         cADpyr_L6BPC_L6_IPC_6_dend-Fluo18_lower_axon-r...  hoc:cADpyr_L6BPC
# 6         cADpyr_L6BPC_L6_TPC:A_6_dend-rat_20140925_RH2_...  hoc:cADpyr_L6BPC
# 7         cADpyr_L6BPC_L6_TPC:A_6_dend-Fluo58_right_axon...  hoc:cADpyr_L6BPC
# 8         cADpyr_L6BPC_L6_TPC:A_6_dend-tkb060523a2_ch5_c...  hoc:cADpyr_L6BPC
# 9         cADpyr_L6BPC_L6_TPC:A_6_rp110125_L5-2_idF_-_Sc...  hoc:cADpyr_L6BPC
#
#            model_type morph_class  \
# node_ids
# 0         biophysical         INT
# 1         biophysical         PYR
# 2         biophysical         PYR
# 3         biophysical         PYR
# 4         biophysical         PYR
# 5         biophysical         PYR
# 6         biophysical         PYR
# 7         biophysical         PYR
# 8         biophysical         PYR
# 9         biophysical         PYR
#
#                                                  morphology     mtype  ...  \
# node_ids                                                               ...
# 0         mtC181200C_idA_-_Scale_x1.000_y0.975_z1.000_-_...   L23_CHC  ...
# 1         dend-mtC090401A_idB_axon-rp101228_L5-1_idA_-_S...    L6_BPC  ...
# 2         dend-vd110330_idA_axon-tkb051205a4_ch3_cl_b_yw...    L6_BPC  ...
# 3         dend-tkb060118b1_ch1_cc1_b_yw_60x_1_axon-rp110...    L6_IPC  ...
# 4         dend-Fluo18_lower_axon-rp110127_L5-3_idC_-_Sca...    L6_IPC  ...
# 5                  dend-Fluo18_lower_axon-rp110127_L5-3_idC    L6_IPC  ...
# 6         dend-rat_20140925_RH2_cell2_axon-rp110125_L5-2...  L6_TPC:A  ...
# 7         dend-Fluo58_right_axon-rp110125_L5-2_idF_-_Clo...  L6_TPC:A  ...
# 8         dend-tkb060523a2_ch5_cc2_n_nb_60x_1_axon-rp110...  L6_TPC:A  ...
# 9            rp110125_L5-2_idF_-_Scale_x1.000_y1.025_z1.000  L6_TPC:A  ...
#
#           orientation_z  region  synapse_class            x            y  \
# node_ids
# 0              0.560684    S1FL            INH  4426.676668 -1365.720303
# 1              0.616289    S1FL            EXC  3704.584482 -1105.618485
# 2             -0.525253    S1FL            EXC  3592.573893 -1084.057134
# 3              0.536812    S1FL            EXC  3627.362786 -1087.181103
# 4             -0.690405    S1FL            EXC  3537.776871 -1029.445880
# 5             -0.320099    S1FL            EXC  3592.676277 -1025.078101
# 6             -0.095833    S1FL            EXC  3639.411619 -1055.078853
# 7             -0.358390    S1FL            EXC  3624.201128 -1018.365265
# 8             -0.428787    S1FL            EXC  3547.925890 -1083.981005
# 9              0.420651    S1FL            EXC  3663.108874 -1035.551752
#
#                     z  @dynamics:holding_current  @dynamics:input_resistance  \
# node_ids
# 0        -1999.555547                  -0.052645                  209.088364
# 1        -2859.425448                  -0.044946                  212.861389
# 2        -2963.768280                  -0.032271                  251.078140
# 3        -2897.810749                  -0.046755                  216.469849
# 4        -2890.783793                  -0.054699                  185.028290
# 5        -2898.148159                  -0.053516                  187.531708
# 6        -2834.399699                  -0.030000                  309.582153
# 7        -2890.523732                  -0.051824                  204.986343
# 8        -2933.071149                  -0.050971                  198.290939
# 9        -2810.042016                  -0.060442                  166.747498
#
#           @dynamics:resting_potential  @dynamics:threshold_current
# node_ids
# 0                          -71.169106                     0.061383
# 1                          -74.256561                     0.059488
# 2                          -75.515778                     0.046605
# 3                          -73.704453                     0.062520
# 4                          -73.785126                     0.079570
# 5                          -73.856956                     0.077297
# 6                          -74.529869                     0.039406
# 7                          -73.461159                     0.069150
# 8                          -73.761887                     0.072182
# 9                          -73.841927                     0.086391
#
# [10 rows x 23 columns]

# %% [markdown]
# ### Defining the circuit simulation

# %%
# Simulation init
sim_neuron_set = obi.PredefinedNeuronSet(node_set="All")
sim_duration = 3000.0  # ms
simulations_initialize = obi.SimulationsForm.Initialize(
    circuit=circuit,
    node_set=sim_neuron_set,
    simulation_length=sim_duration,
)

# Stimuli
stim_neuron_set = obi.PredefinedNeuronSet(node_set="All", sample_percentage=[50, 100])
stim_times = obi.RegularTimestamps(start_time=0.0, number_of_repetitions=3, interval=1000.0)  # in ms!!
current_stimulus = obi.ConstantCurrentClampSomaticStimulus(timestamps=stim_times, duration=5.0, neuron_set=stim_neuron_set, amplitude=[0.2, 0.5])

# Recordings
rec_neuron_set = obi.PredefinedNeuronSet(node_set="All")
v_recording = obi.SomaVoltageRecording(start_time=0.0, end_time=sim_duration, neuron_set=rec_neuron_set)

"""
Fill form with Blocks
"""
simulations_form = obi.SimulationsForm(
                                    initialize=simulations_initialize,
                                    intracellular_location_sets={},
                                    extracellular_location_sets={},
                                    neuron_sets={"SimNrnSet": sim_neuron_set, "StimNrnSet": stim_neuron_set, "RecNrnSet": rec_neuron_set},
                                    synapse_sets={},
                                    timestamps={"StimTimes": stim_times},
                                    stimuli={"IStim": current_stimulus},
                                    recordings={"SomaVoltRec": v_recording},
                                    )

# %%
simulations_form.model_dump(mode="json")
# Out:
# {'type': 'SimulationsForm',
#  'timestamps': {'StimTimes': {'type': 'RegularTimestamps',
#    'start_time': 0.0,
#    'simulation_level_name': 'StimTimes',
#    'number_of_repetitions': 3,
#    'interval': 1000.0}},
#  'stimuli': {'IStim': {'type': 'ConstantCurrentClampSomaticStimulus',
#    'timestamps': {'type': 'RegularTimestamps',
#     'start_time': 0.0,
#     'simulation_level_name': 'StimTimes',
#     'number_of_repetitions': 3,
#     'interval': 1000.0},
#    'simulation_level_name': 'IStim',
#    'delay': 0.0,
#    'duration': 5.0,
#    'neuron_set': {'type': 'PredefinedNeuronSet',
#     'simulation_level_name': 'StimNrnSet',
#     'sample_percentage': [5, 10],
#     'sample_seed': 0,
#     'node_set': 'All'},
#    'represents_physical_electrode': False,
#    'amplitude': [0.2, 0.5]}},
#  'recordings': {'SomaVoltRec': {'type': 'SomaVoltageRecording',
#    'start_time': 0.0,
#    'end_time': 3000.0,
#    'dt': 0.1,
#    'simulation_level_name': 'SomaVoltRec',
#    'neuron_set': {'type': 'PredefinedNeuronSet',
#     'simulation_level_name': 'RecNrnSet',
#     'sample_percentage': None,
#     'sample_seed': 0,
#     'node_set': 'All'}}},
#  'neuron_sets': {'SimNrnSet': {'type': 'PredefinedNeuronSet',
#    'simulation_level_name': 'SimNrnSet',
#    'sample_percentage': None,
#    'sample_seed': 0,
#    'node_set': 'All'},
#   'StimNrnSet': {'type': 'PredefinedNeuronSet',
#    'simulation_level_name': 'StimNrnSet',
#    'sample_percentage': [5, 10],
#    'sample_seed': 0,
#    'node_set': 'All'},
#   'RecNrnSet': {'type': 'PredefinedNeuronSet',
#    'simulation_level_name': 'RecNrnSet',
#    'sample_percentage': None,
#    'sample_seed': 0,
#    'node_set': 'All'}},
#  'synapse_sets': {},
#  'intracellular_location_sets': {},
#  'extracellular_location_sets': {},
#  'initialize': {'type': 'SimulationsForm.Initialize',
#   'circuit': {'type': 'Circuit',
#    'name': 'N_10__top_nodes_dim6',
#    'path': '../../examples/data/tiny_circuits/N_10__top_nodes_dim6/circuit_config.json'},
#   'simulation_length': 3000.0,
#   'node_set': {'type': 'PredefinedNeuronSet',
#    'simulation_level_name': 'SimNrnSet',
#    'sample_percentage': None,
#    'sample_seed': 0,
#    'node_set': 'All'},
#   'sample_seed': 1,
#   'extracellular_calcium_concentration': 1.1,
#   'v_init': -80.0,
#   'spike_location': 'soma',
#   'sonata_version': 1,
#   'target_simulator': 'CORENEURON',
#   'timestep': 0.025}}

# %%
grid_scan = obi.GridScan(form=simulations_form, output_root='../../../obi-output/tiny_circuit_simulation_campaign/grid_scan')
grid_scan.multiple_value_parameters(display=True)
grid_scan.coordinate_parameters(display=True)
# grid_scan.coordinate_instances(display=True)
grid_scan.execute(processing_method='generate')
# Out:
# MULTIPLE VALUE PARAMETERS
# stimuli.IStim.amplitude: [0.2, 0.5]
# neuron_sets.StimNrnSet.sample_percentage: [5, 10]
#
# COORDINATE PARAMETERS
# stimuli.IStim.amplitude: 0.2, neuron_sets.StimNrnSet.sample_percentage: 5
# stimuli.IStim.amplitude: 0.2, neuron_sets.StimNrnSet.sample_percentage: 10
# stimuli.IStim.amplitude: 0.5, neuron_sets.StimNrnSet.sample_percentage: 5
# stimuli.IStim.amplitude: 0.5, neuron_sets.StimNrnSet.sample_percentage: 10
# create_bbp_workflow_campaign_config() not yet complete.
# {0: None, 1: None, 2: None, 3: None}

# %%
# Deserialization
# grid_scan_ds = obi.deserialize_obi_object_from_json_file("../../../obi-output/tiny_circuit_simulations/grid_scan/run_scan_config.json")
